# %%
from utils import TremorDataset

# %%
dataset = TremorDataset(filepath="../data/tremor_data.csv")
dataset.visualize()

# %%
dataset2 = TremorDataset(filepath="../data/Dataset.csv")
dataset2.visualize(first_n=1000)
